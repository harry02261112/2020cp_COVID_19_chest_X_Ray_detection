# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %matplotlib inline 
import numpy as np 
import cv2
import csv
import matplotlib.pyplot as plt 
import random

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import LeakyReLU
from keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
# Out:
# Using TensorFlow backend.

# %%
from os import listdir
from os.path import isfile, join
Covid_train_files = [f for f in listdir("/content/drive/My Drive/Colab Notebooks/Covid/train") if f.startswith('.') == False and isfile(join("/content/drive/My Drive/Colab Notebooks/Covid/train", f))]
Covid_test_files = [f for f in listdir("/content/drive/My Drive/Colab Notebooks/Covid/test") if f.startswith('.') == False and isfile(join("/content/drive/My Drive/Colab Notebooks/Covid/test", f))]
Normal_train_files = [f for f in listdir("/content/drive/My Drive/Colab Notebooks/Normal/train") if  f.startswith('.') == False ]
Normal_test_files = [f for f in listdir("/content/drive/My Drive/Colab Notebooks/Normal/test") if  f.startswith('.') == False and isfile(join("/content/drive/My Drive/Colab Notebooks/Normal/test", f))]
Pneumonia_train_files = [f for f in listdir("/content/drive/My Drive/Colab Notebooks/Pneumonia/train") if  f.startswith('.') == False and isfile(join("/content/drive/My Drive/Colab Notebooks/Pneumonia/train", f))]
Pneumonia_test_files = [f for f in listdir("/content/drive/My Drive/Colab Notebooks/Pneumonia/test") if  f.startswith('.') == False and isfile(join("/content/drive/My Drive/Colab Notebooks/Pneumonia/test", f))]

# %%
len(Normal_train_files)
# Out:
# 180

# %%
def read_data(file_names_list, data_list, labels_list, path, label):
  for i in range(len(file_names_list)):
    img = cv2.imread(path + file_names_list[i])
    img = cv2.resize(img,(224,224))
    data_list.append(img)
    labels_list.append(label)
  return data_list, labels_list

# %%
train_list = []
test_list = []
train_labels = []
test_labels = []

path = "/content/drive/My Drive/Colab Notebooks/Covid/train/"
label = 0
train_list, train_labels = read_data(Covid_train_files, train_list, train_labels, path, label)
print(len(train_list),len(train_labels))
path = "/content/drive/My Drive/Colab Notebooks/Normal/train/"
label = 1
train_list, train_labels = read_data(Normal_train_files, train_list, train_labels, path, label)
print(len(train_list),len(train_labels))
path = "/content/drive/My Drive/Colab Notebooks/Pneumonia/train/"
label = 2
train_list, train_labels = read_data(Pneumonia_train_files, train_list, train_labels, path, label)
print(len(train_list),len(train_labels))
path = "/content/drive/My Drive/Colab Notebooks/Covid/test/"
label = 0
test_list, test_labels = read_data(Covid_test_files, test_list, test_labels, path, label)
print(len(test_list),len(test_labels))
path = "/content/drive/My Drive/Colab Notebooks/Normal/test/"
label = 1
test_list, test_labels = read_data(Normal_test_files, test_list, test_labels, path, label)
print(len(test_list),len(test_labels))
path = "/content/drive/My Drive/Colab Notebooks/Pneumonia/test/"
label = 2
test_list, test_labels = read_data(Pneumonia_test_files, test_list, test_labels, path, label)
print(len(test_list),len(test_labels))
# Out:
# 179 179
# 359 359
# 539 539
# 30 30
# 60 60
# 90 90

# %%
k = 10
folds = list(StratifiedKFold(n_splits = k, shuffle=True, random_state=1).split(train_list, train_labels))

# %%
def one_hot(l):
    for i in range(len(l)):
        if(l[i] == 0):
            l[i] = [1,0,0]
        if(l[i] == 1):
            l[i] = [0,1,0]
        if(l[i] == 2):
            l[i] = [0,0,1]
    return l

# %%
train_labels = one_hot(train_labels)
test_labels = one_hot(test_labels)

# %%
train_list = np.array(train_list)
train_labels = np.array(train_labels)
test_list = np.array(test_list)
test_labels = np.array(test_labels)

# %%
def ResNet50_get():
    K.set_learning_phase(1)
    ModelX = ResNet50(weights="imagenet", include_top=False,
                      input_tensor=Input(shape=(224, 224, 3)))
    ModelX_out = ModelX.layers[-1].output
    ModelX_out = GlobalAveragePooling2D()(ModelX_out)
    ModelX_out = Dense(512, activation = "relu", name="dense_one")(ModelX_out)
    ModelX_out = Dropout(0.3, name="dropout_add1")(ModelX_out)
    ModelX_out = Dense(512, activation = "relu", name="dense_two")(ModelX_out)
    ModelX_out = Dropout(0.5, name="dropout_add2")(ModelX_out)
    ModelX_out = Dense(3, activation="softmax", name="dense_out")(ModelX_out)
    ModelDN = Model(ModelX.input, ModelX_out)
    #for layer in ModelX.layers:
      #if hasattr(layer, 'moving_mean') and hasattr(layer, 'moving_variance'):
         # layer.trainable = True
         # K.eval(K.update(layer.moving_mean, K.zeros_like(layer.moving_mean)))
         # K.eval(K.update(layer.moving_variance, K.zeros_like(layer.moving_variance)))
    #else:
        #layer.trainable = False
    for layer in ModelX.layers:
      layer.trainable = False

    
    opt = SGD(lr=0.01, decay=0.01 / 25)
    ModelDN.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])
    
    return(ModelDN)

# %%
model = DenseNet_get()
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_7[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense_one (Dense)               (None, 512)          1049088     global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_add1 (Dropout)          (None, 512)          0           dense_one[0][0]
# __________________________________________________________________________________________________
# dense_two (Dense)               (None, 512)          262656      dropout_add1[0][0]
# __________________________________________________________________________________________________
# dropout_add2 (Dropout)          (None, 512)          0           dense_two[0][0]
# __________________________________________________________________________________________________
# dense_out (Dense)               (None, 3)            1539        dropout_add2[0][0]
# ==================================================================================================
# Total params: 24,900,995
# Trainable params: 1,313,283
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='/content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/model.png')

# %%
trainAug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest")

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience =  5)
checkpoint_callback = ModelCheckpoint("/content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
len(train_list)
# Out:
# 539

# %%
models_each_folds = []
models_evaluations = []
HXs = []

for j, (train_idx, val_idx) in enumerate(folds):
    
    print('\nFold ',j)
    X_train_app = train_list[train_idx]
    Y_train_app = train_labels[train_idx]
    VALX = train_list[val_idx]
    VALY= train_labels[val_idx]
    
    print("[INFO] training head...")
    
    modelX = DenseNet_get()
    
    HX = modelX.fit_generator(
    trainAug.flow(X_train_app,Y_train_app, batch_size=8),
    steps_per_epoch=len(X_train_app) // 8,
    validation_data=(VALX, VALY),
    validation_steps=len(VALX) // 8,
    callbacks=[early_stopping_callback, checkpoint_callback],
    epochs=30)
    
    K.set_learning_phase(0)
    predIdxsX = modelX.predict(test_list.astype('float16'), batch_size=8)
    predIdxsX = np.argmax(predIdxsX, axis=1)
    print(classification_report(test_labels.argmax(axis=1), predIdxsX,target_names=["COVID-19","NORMAL","PNEUMONIA"]))
    
    models_each_folds.append(modelX)
    HXs.append(HX)
    
    Loss, Acc = modelX.evaluate(test_list,test_labels)
    models_evaluations.append([Loss, Acc])
    print("(Loss, Acc):",modelX.evaluate(test_list,test_labels))
# Out:
# Fold  0
# [INFO] training head...
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6556 - accuracy: 0.7568
# Epoch 00001: val_loss improved from inf to 0.40360, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 10s 171ms/step - loss: 0.6556 - accuracy: 0.7568 - val_loss: 0.4036 - val_accuracy: 0.8148
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.8595
# Epoch 00002: val_loss improved from 0.40360 to 0.26408, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 111ms/step - loss: 0.3700 - accuracy: 0.8595 - val_loss: 0.2641 - val_accuracy: 0.9074
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2930 - accuracy: 0.8889
# Epoch 00003: val_loss improved from 0.26408 to 0.25129, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 109ms/step - loss: 0.2930 - accuracy: 0.8889 - val_loss: 0.2513 - val_accuracy: 0.8704
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2620 - accuracy: 0.8931
# Epoch 00004: val_loss improved from 0.25129 to 0.22201, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 110ms/step - loss: 0.2620 - accuracy: 0.8931 - val_loss: 0.2220 - val_accuracy: 0.9074
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9308
# Epoch 00005: val_loss did not improve from 0.22201
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1926 - accuracy: 0.9308 - val_loss: 0.4056 - val_accuracy: 0.8333
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.9036
# Epoch 00006: val_loss did not improve from 0.22201
# 60/60 [==============================] - 6s 101ms/step - loss: 0.2572 - accuracy: 0.9036 - val_loss: 0.2983 - val_accuracy: 0.8519
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1595 - accuracy: 0.9434
# Epoch 00007: val_loss did not improve from 0.22201
# 60/60 [==============================] - 6s 102ms/step - loss: 0.1595 - accuracy: 0.9434 - val_loss: 0.2484 - val_accuracy: 0.9074
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9308
# Epoch 00008: val_loss improved from 0.22201 to 0.14256, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 8s 133ms/step - loss: 0.1786 - accuracy: 0.9308 - val_loss: 0.1426 - val_accuracy: 0.9444
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1509 - accuracy: 0.9329
# Epoch 00009: val_loss did not improve from 0.14256
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1509 - accuracy: 0.9329 - val_loss: 0.1562 - val_accuracy: 0.9444
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9392
# Epoch 00010: val_loss did not improve from 0.14256
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1420 - accuracy: 0.9392 - val_loss: 0.1929 - val_accuracy: 0.9074
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9371
# Epoch 00011: val_loss did not improve from 0.14256
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1693 - accuracy: 0.9371 - val_loss: 0.2127 - val_accuracy: 0.9074
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9521
# Epoch 00012: val_loss did not improve from 0.14256
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1486 - accuracy: 0.9521 - val_loss: 0.3074 - val_accuracy: 0.8704
# Epoch 13/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.9434
# Epoch 00013: val_loss did not improve from 0.14256
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1467 - accuracy: 0.9434 - val_loss: 0.2047 - val_accuracy: 0.9074
#               precision    recall  f1-score   support
#
#     COVID-19       0.88      0.97      0.92        30
#       NORMAL       0.93      0.83      0.88        30
#    PNEUMONIA       0.93      0.93      0.93        30
#
#     accuracy                           0.91        90
#    macro avg       0.91      0.91      0.91        90
# weighted avg       0.91      0.91      0.91        90
#
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4030 - accuracy: 0.9111
# 3/3 [==============================] - 0s 71ms/step - loss: 0.4030 - accuracy: 0.9111
# (Loss, Acc): [0.40297731757164, 0.9111111164093018]
#
# Fold  1
# [INFO] training head...
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7095 - accuracy: 0.6918
# Epoch 00001: val_loss did not improve from 0.14256
# 60/60 [==============================] - 7s 112ms/step - loss: 0.7095 - accuracy: 0.6918 - val_loss: 0.2312 - val_accuracy: 0.9259
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3487 - accuracy: 0.8658
# Epoch 00002: val_loss did not improve from 0.14256
# 60/60 [==============================] - 6s 98ms/step - loss: 0.3487 - accuracy: 0.8658 - val_loss: 0.3187 - val_accuracy: 0.8148
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3441 - accuracy: 0.8658
# Epoch 00003: val_loss did not improve from 0.14256
# 60/60 [==============================] - 6s 98ms/step - loss: 0.3441 - accuracy: 0.8658 - val_loss: 0.2834 - val_accuracy: 0.9259
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3192 - accuracy: 0.8784
# Epoch 00004: val_loss did not improve from 0.14256
# 60/60 [==============================] - 6s 99ms/step - loss: 0.3192 - accuracy: 0.8784 - val_loss: 0.1777 - val_accuracy: 0.9074
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.9099
# Epoch 00005: val_loss did not improve from 0.14256
# 60/60 [==============================] - 6s 98ms/step - loss: 0.2423 - accuracy: 0.9099 - val_loss: 0.1816 - val_accuracy: 0.9259
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.9161
# Epoch 00006: val_loss improved from 0.14256 to 0.13687, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 8s 129ms/step - loss: 0.2172 - accuracy: 0.9161 - val_loss: 0.1369 - val_accuracy: 0.9444
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9161
# Epoch 00007: val_loss did not improve from 0.13687
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2336 - accuracy: 0.9161 - val_loss: 0.1450 - val_accuracy: 0.9444
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9203
# Epoch 00008: val_loss improved from 0.13687 to 0.11315, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 122ms/step - loss: 0.1979 - accuracy: 0.9203 - val_loss: 0.1131 - val_accuracy: 0.9444
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1895 - accuracy: 0.9203
# Epoch 00009: val_loss did not improve from 0.11315
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1895 - accuracy: 0.9203 - val_loss: 0.2491 - val_accuracy: 0.9074
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1932 - accuracy: 0.9371
# Epoch 00010: val_loss improved from 0.11315 to 0.11183, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 8s 130ms/step - loss: 0.1932 - accuracy: 0.9371 - val_loss: 0.1118 - val_accuracy: 0.9630
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9203
# Epoch 00011: val_loss did not improve from 0.11183
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1883 - accuracy: 0.9203 - val_loss: 0.1953 - val_accuracy: 0.9259
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9287
# Epoch 00012: val_loss improved from 0.11183 to 0.10590, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 122ms/step - loss: 0.1749 - accuracy: 0.9287 - val_loss: 0.1059 - val_accuracy: 0.9630
# Epoch 13/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 0.9245
# Epoch 00013: val_loss improved from 0.10590 to 0.08529, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 110ms/step - loss: 0.1602 - accuracy: 0.9245 - val_loss: 0.0853 - val_accuracy: 0.9630
# Epoch 14/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9392
# Epoch 00014: val_loss improved from 0.08529 to 0.08437, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 111ms/step - loss: 0.1568 - accuracy: 0.9392 - val_loss: 0.0844 - val_accuracy: 0.9444
# Epoch 15/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9560
# Epoch 00015: val_loss did not improve from 0.08437
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1149 - accuracy: 0.9560 - val_loss: 0.0968 - val_accuracy: 0.9444
# Epoch 16/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9518
# Epoch 00016: val_loss improved from 0.08437 to 0.07426, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 112ms/step - loss: 0.1164 - accuracy: 0.9518 - val_loss: 0.0743 - val_accuracy: 0.9815
# Epoch 17/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9371
# Epoch 00017: val_loss did not improve from 0.07426
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1490 - accuracy: 0.9371 - val_loss: 0.1153 - val_accuracy: 0.9444
# Epoch 18/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9560
# Epoch 00018: val_loss did not improve from 0.07426
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1207 - accuracy: 0.9560 - val_loss: 0.1061 - val_accuracy: 0.9630
# Epoch 19/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9560
# Epoch 00019: val_loss improved from 0.07426 to 0.07253, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 122ms/step - loss: 0.1343 - accuracy: 0.9560 - val_loss: 0.0725 - val_accuracy: 0.9630
# Epoch 20/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1308 - accuracy: 0.9413
# Epoch 00020: val_loss did not improve from 0.07253
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1308 - accuracy: 0.9413 - val_loss: 0.0951 - val_accuracy: 0.9630
# Epoch 21/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9518
# Epoch 00021: val_loss improved from 0.07253 to 0.06371, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 121ms/step - loss: 0.1286 - accuracy: 0.9518 - val_loss: 0.0637 - val_accuracy: 0.9630
# Epoch 22/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.9434
# Epoch 00022: val_loss did not improve from 0.06371
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1455 - accuracy: 0.9434 - val_loss: 0.0667 - val_accuracy: 0.9630
# Epoch 23/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 0.9497
# Epoch 00023: val_loss improved from 0.06371 to 0.06237, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 119ms/step - loss: 0.1297 - accuracy: 0.9497 - val_loss: 0.0624 - val_accuracy: 0.9815
# Epoch 24/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9476
# Epoch 00024: val_loss improved from 0.06237 to 0.05725, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 7s 111ms/step - loss: 0.1252 - accuracy: 0.9476 - val_loss: 0.0573 - val_accuracy: 1.0000
# Epoch 25/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9602
# Epoch 00025: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1081 - accuracy: 0.9602 - val_loss: 0.1114 - val_accuracy: 0.9630
# Epoch 26/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9497
# Epoch 00026: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1124 - accuracy: 0.9497 - val_loss: 0.0887 - val_accuracy: 0.9444
# Epoch 27/30
# 60/60 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9706
# Epoch 00027: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 98ms/step - loss: 0.0946 - accuracy: 0.9706 - val_loss: 0.1239 - val_accuracy: 0.9630
# Epoch 28/30
# 60/60 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9706
# Epoch 00028: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.0879 - accuracy: 0.9706 - val_loss: 0.0752 - val_accuracy: 0.9444
# Epoch 29/30
# 60/60 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9706
# Epoch 00029: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.0871 - accuracy: 0.9706 - val_loss: 0.0586 - val_accuracy: 0.9815
#               precision    recall  f1-score   support
#
#     COVID-19       0.88      0.97      0.92        30
#       NORMAL       0.86      0.80      0.83        30
#    PNEUMONIA       0.90      0.87      0.88        30
#
#     accuracy                           0.88        90
#    macro avg       0.88      0.88      0.88        90
# weighted avg       0.88      0.88      0.88        90
#
# 3/3 [==============================] - 0s 71ms/step - loss: 0.3815 - accuracy: 0.8778
# 3/3 [==============================] - 0s 72ms/step - loss: 0.3815 - accuracy: 0.8778
# (Loss, Acc): [0.3814787268638611, 0.8777777552604675]
#
# Fold  2
# [INFO] training head...
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7412 - accuracy: 0.7125
# Epoch 00001: val_loss did not improve from 0.05725
# 60/60 [==============================] - 7s 113ms/step - loss: 0.7412 - accuracy: 0.7125 - val_loss: 0.2018 - val_accuracy: 0.9259
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3945 - accuracy: 0.8449
# Epoch 00002: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 101ms/step - loss: 0.3945 - accuracy: 0.8449 - val_loss: 0.6079 - val_accuracy: 0.6481
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8742
# Epoch 00003: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 101ms/step - loss: 0.3137 - accuracy: 0.8742 - val_loss: 0.1823 - val_accuracy: 0.9444
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.8952
# Epoch 00004: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 101ms/step - loss: 0.2889 - accuracy: 0.8952 - val_loss: 0.1244 - val_accuracy: 0.9444
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9140
# Epoch 00005: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 100ms/step - loss: 0.2082 - accuracy: 0.9140 - val_loss: 0.1014 - val_accuracy: 0.9444
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2306 - accuracy: 0.9119
# Epoch 00006: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2306 - accuracy: 0.9119 - val_loss: 0.1340 - val_accuracy: 0.9259
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2074 - accuracy: 0.9224
# Epoch 00007: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2074 - accuracy: 0.9224 - val_loss: 0.0980 - val_accuracy: 0.9259
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1977 - accuracy: 0.9119
# Epoch 00008: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1977 - accuracy: 0.9119 - val_loss: 0.0915 - val_accuracy: 0.9815
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.9329
# Epoch 00009: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1755 - accuracy: 0.9329 - val_loss: 0.0838 - val_accuracy: 0.9630
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9308
# Epoch 00010: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1576 - accuracy: 0.9308 - val_loss: 0.1360 - val_accuracy: 0.9259
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9203
# Epoch 00011: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1882 - accuracy: 0.9203 - val_loss: 0.0867 - val_accuracy: 0.9444
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9392
# Epoch 00012: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1558 - accuracy: 0.9392 - val_loss: 0.0773 - val_accuracy: 0.9630
# Epoch 13/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9560
# Epoch 00013: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1320 - accuracy: 0.9560 - val_loss: 0.0881 - val_accuracy: 0.9444
# Epoch 14/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9434
# Epoch 00014: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1525 - accuracy: 0.9434 - val_loss: 0.1429 - val_accuracy: 0.9259
# Epoch 15/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9518
# Epoch 00015: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1372 - accuracy: 0.9518 - val_loss: 0.0638 - val_accuracy: 0.9815
# Epoch 16/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1350 - accuracy: 0.9497
# Epoch 00016: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 98ms/step - loss: 0.1350 - accuracy: 0.9497 - val_loss: 0.0648 - val_accuracy: 0.9815
# Epoch 17/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9455
# Epoch 00017: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1089 - accuracy: 0.9455 - val_loss: 0.0888 - val_accuracy: 0.9444
# Epoch 18/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1350 - accuracy: 0.9476
# Epoch 00018: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1350 - accuracy: 0.9476 - val_loss: 0.0618 - val_accuracy: 0.9815
# Epoch 19/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9602
# Epoch 00019: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1112 - accuracy: 0.9602 - val_loss: 0.0679 - val_accuracy: 0.9630
# Epoch 20/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9560
# Epoch 00020: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1347 - accuracy: 0.9560 - val_loss: 0.0597 - val_accuracy: 0.9815
# Epoch 21/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9602
# Epoch 00021: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 98ms/step - loss: 0.1031 - accuracy: 0.9602 - val_loss: 0.0725 - val_accuracy: 0.9630
# Epoch 22/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9560
# Epoch 00022: val_loss did not improve from 0.05725
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1134 - accuracy: 0.9560 - val_loss: 0.0811 - val_accuracy: 0.9630
# Epoch 23/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9539
# Epoch 00023: val_loss improved from 0.05725 to 0.04424, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 8s 132ms/step - loss: 0.1116 - accuracy: 0.9539 - val_loss: 0.0442 - val_accuracy: 1.0000
# Epoch 24/30
# 60/60 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9644
# Epoch 00024: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.0825 - accuracy: 0.9644 - val_loss: 0.0451 - val_accuracy: 0.9815
# Epoch 25/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9644
# Epoch 00025: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1099 - accuracy: 0.9644 - val_loss: 0.0481 - val_accuracy: 0.9815
# Epoch 26/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9623
# Epoch 00026: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1034 - accuracy: 0.9623 - val_loss: 0.0497 - val_accuracy: 0.9815
# Epoch 27/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9476
# Epoch 00027: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1081 - accuracy: 0.9476 - val_loss: 0.0969 - val_accuracy: 0.9630
# Epoch 28/30
# 60/60 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9769
# Epoch 00028: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.0885 - accuracy: 0.9769 - val_loss: 0.0531 - val_accuracy: 0.9630
#               precision    recall  f1-score   support
#
#     COVID-19       0.88      0.97      0.92        30
#       NORMAL       0.76      0.83      0.79        30
#    PNEUMONIA       0.92      0.73      0.81        30
#
#     accuracy                           0.84        90
#    macro avg       0.85      0.84      0.84        90
# weighted avg       0.85      0.84      0.84        90
#
# 3/3 [==============================] - 0s 72ms/step - loss: 0.3897 - accuracy: 0.8444
# 3/3 [==============================] - 0s 73ms/step - loss: 0.3897 - accuracy: 0.8444
# (Loss, Acc): [0.38973528146743774, 0.8444444537162781]
#
# Fold  3
# [INFO] training head...
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6655 - accuracy: 0.7317
# Epoch 00001: val_loss did not improve from 0.04424
# 60/60 [==============================] - 7s 115ms/step - loss: 0.6655 - accuracy: 0.7317 - val_loss: 0.5962 - val_accuracy: 0.7963
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.8763
# Epoch 00002: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 100ms/step - loss: 0.3528 - accuracy: 0.8763 - val_loss: 0.5448 - val_accuracy: 0.8704
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2911 - accuracy: 0.8805
# Epoch 00003: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2911 - accuracy: 0.8805 - val_loss: 0.4247 - val_accuracy: 0.8889
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.9099
# Epoch 00004: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2594 - accuracy: 0.9099 - val_loss: 0.4172 - val_accuracy: 0.8889
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.9057
# Epoch 00005: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2464 - accuracy: 0.9057 - val_loss: 0.5064 - val_accuracy: 0.8704
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9329
# Epoch 00006: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1744 - accuracy: 0.9329 - val_loss: 0.2780 - val_accuracy: 0.9259
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1829 - accuracy: 0.9392
# Epoch 00007: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 98ms/step - loss: 0.1829 - accuracy: 0.9392 - val_loss: 0.3188 - val_accuracy: 0.9259
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1922 - accuracy: 0.9287
# Epoch 00008: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1922 - accuracy: 0.9287 - val_loss: 0.4230 - val_accuracy: 0.8889
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1308 - accuracy: 0.9392
# Epoch 00009: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1308 - accuracy: 0.9392 - val_loss: 0.4793 - val_accuracy: 0.8889
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.9203
# Epoch 00010: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2039 - accuracy: 0.9203 - val_loss: 0.2784 - val_accuracy: 0.9259
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9560
# Epoch 00011: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1483 - accuracy: 0.9560 - val_loss: 0.3400 - val_accuracy: 0.9259
#               precision    recall  f1-score   support
#
#     COVID-19       0.94      0.97      0.95        30
#       NORMAL       0.73      0.90      0.81        30
#    PNEUMONIA       0.91      0.67      0.77        30
#
#     accuracy                           0.84        90
#    macro avg       0.86      0.84      0.84        90
# weighted avg       0.86      0.84      0.84        90
#
# 3/3 [==============================] - 0s 73ms/step - loss: 0.3715 - accuracy: 0.8444
# 3/3 [==============================] - 0s 72ms/step - loss: 0.3715 - accuracy: 0.8444
# (Loss, Acc): [0.37152624130249023, 0.8444444537162781]
#
# Fold  4
# [INFO] training head...
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6750 - accuracy: 0.7338
# Epoch 00001: val_loss did not improve from 0.04424
# 60/60 [==============================] - 7s 114ms/step - loss: 0.6750 - accuracy: 0.7338 - val_loss: 0.1956 - val_accuracy: 0.9444
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8721
# Epoch 00002: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 100ms/step - loss: 0.3649 - accuracy: 0.8721 - val_loss: 0.1324 - val_accuracy: 0.9444
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3402 - accuracy: 0.8616
# Epoch 00003: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.3402 - accuracy: 0.8616 - val_loss: 0.1499 - val_accuracy: 0.9444
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2929 - accuracy: 0.8847
# Epoch 00004: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2929 - accuracy: 0.8847 - val_loss: 0.1076 - val_accuracy: 0.9630
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2662 - accuracy: 0.8910
# Epoch 00005: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2662 - accuracy: 0.8910 - val_loss: 0.1529 - val_accuracy: 0.9444
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.9224
# Epoch 00006: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 100ms/step - loss: 0.2302 - accuracy: 0.9224 - val_loss: 0.1891 - val_accuracy: 0.9444
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2070 - accuracy: 0.9266
# Epoch 00007: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 100ms/step - loss: 0.2070 - accuracy: 0.9266 - val_loss: 0.1050 - val_accuracy: 0.9444
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.9371
# Epoch 00008: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1683 - accuracy: 0.9371 - val_loss: 0.0869 - val_accuracy: 0.9630
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9266
# Epoch 00009: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1931 - accuracy: 0.9266 - val_loss: 0.0482 - val_accuracy: 1.0000
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9371
# Epoch 00010: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1613 - accuracy: 0.9371 - val_loss: 0.0780 - val_accuracy: 0.9630
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.9413
# Epoch 00011: val_loss did not improve from 0.04424
# 60/60 [==============================] - 6s 103ms/step - loss: 0.1661 - accuracy: 0.9413 - val_loss: 0.1705 - val_accuracy: 0.9444
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.9308
# Epoch 00012: val_loss improved from 0.04424 to 0.03776, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 60/60 [==============================] - 8s 130ms/step - loss: 0.1581 - accuracy: 0.9308 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 13/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1670 - accuracy: 0.9413
# Epoch 00013: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1670 - accuracy: 0.9413 - val_loss: 0.0468 - val_accuracy: 0.9815
# Epoch 14/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9350
# Epoch 00014: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 103ms/step - loss: 0.1696 - accuracy: 0.9350 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 15/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9497
# Epoch 00015: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1406 - accuracy: 0.9497 - val_loss: 0.0674 - val_accuracy: 0.9630
# Epoch 16/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9686
# Epoch 00016: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1092 - accuracy: 0.9686 - val_loss: 0.1011 - val_accuracy: 0.9444
# Epoch 17/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9560
# Epoch 00017: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1255 - accuracy: 0.9560 - val_loss: 0.0638 - val_accuracy: 0.9630
#               precision    recall  f1-score   support
#
#     COVID-19       0.79      1.00      0.88        30
#       NORMAL       0.85      0.77      0.81        30
#    PNEUMONIA       0.96      0.80      0.87        30
#
#     accuracy                           0.86        90
#    macro avg       0.87      0.86      0.85        90
# weighted avg       0.87      0.86      0.85        90
#
# 3/3 [==============================] - 0s 73ms/step - loss: 0.4908 - accuracy: 0.8556
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4908 - accuracy: 0.8556
# (Loss, Acc): [0.4908461272716522, 0.855555534362793]
#
# Fold  5
# [INFO] training head...
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6374 - accuracy: 0.7463
# Epoch 00001: val_loss did not improve from 0.03776
# 60/60 [==============================] - 7s 112ms/step - loss: 0.6374 - accuracy: 0.7463 - val_loss: 0.2883 - val_accuracy: 0.8889
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.8700
# Epoch 00002: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.3300 - accuracy: 0.8700 - val_loss: 0.4156 - val_accuracy: 0.8148
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2741 - accuracy: 0.8973
# Epoch 00003: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2741 - accuracy: 0.8973 - val_loss: 0.2441 - val_accuracy: 0.9074
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.9015
# Epoch 00004: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2503 - accuracy: 0.9015 - val_loss: 0.7678 - val_accuracy: 0.7963
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2345 - accuracy: 0.9099
# Epoch 00005: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2345 - accuracy: 0.9099 - val_loss: 0.4911 - val_accuracy: 0.8519
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9099
# Epoch 00006: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2395 - accuracy: 0.9099 - val_loss: 0.2178 - val_accuracy: 0.8889
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2072 - accuracy: 0.9161
# Epoch 00007: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2072 - accuracy: 0.9161 - val_loss: 0.1682 - val_accuracy: 0.9444
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9329
# Epoch 00008: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1750 - accuracy: 0.9329 - val_loss: 0.2168 - val_accuracy: 0.8889
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1680 - accuracy: 0.9308
# Epoch 00009: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1680 - accuracy: 0.9308 - val_loss: 0.2955 - val_accuracy: 0.8889
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1712 - accuracy: 0.9308
# Epoch 00010: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1712 - accuracy: 0.9308 - val_loss: 0.2653 - val_accuracy: 0.8889
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9350
# Epoch 00011: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1750 - accuracy: 0.9350 - val_loss: 0.3592 - val_accuracy: 0.8889
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9350
# Epoch 00012: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1535 - accuracy: 0.9350 - val_loss: 0.2790 - val_accuracy: 0.8889
#               precision    recall  f1-score   support
#
#     COVID-19       0.94      0.97      0.95        30
#       NORMAL       0.79      0.90      0.84        30
#    PNEUMONIA       0.92      0.77      0.84        30
#
#     accuracy                           0.88        90
#    macro avg       0.88      0.88      0.88        90
# weighted avg       0.88      0.88      0.88        90
#
# 3/3 [==============================] - 0s 73ms/step - loss: 0.3206 - accuracy: 0.8778
# 3/3 [==============================] - 0s 71ms/step - loss: 0.3206 - accuracy: 0.8778
# (Loss, Acc): [0.32060670852661133, 0.8777777552604675]
#
# Fold  6
# [INFO] training head...
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7436 - accuracy: 0.7191
# Epoch 00001: val_loss did not improve from 0.03776
# 60/60 [==============================] - 7s 112ms/step - loss: 0.7436 - accuracy: 0.7191 - val_loss: 0.2257 - val_accuracy: 0.9259
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.4102 - accuracy: 0.8407
# Epoch 00002: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.4102 - accuracy: 0.8407 - val_loss: 0.3051 - val_accuracy: 0.9259
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2994 - accuracy: 0.8973
# Epoch 00003: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.2994 - accuracy: 0.8973 - val_loss: 0.1258 - val_accuracy: 0.9444
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.9119
# Epoch 00004: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.2478 - accuracy: 0.9119 - val_loss: 0.3520 - val_accuracy: 0.8333
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2420 - accuracy: 0.8973
# Epoch 00005: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2420 - accuracy: 0.8973 - val_loss: 0.1072 - val_accuracy: 0.9815
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9350
# Epoch 00006: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1980 - accuracy: 0.9350 - val_loss: 0.1354 - val_accuracy: 0.9444
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9119
# Epoch 00007: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2131 - accuracy: 0.9119 - val_loss: 0.1183 - val_accuracy: 0.9259
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9161
# Epoch 00008: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1897 - accuracy: 0.9161 - val_loss: 0.1476 - val_accuracy: 0.9444
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1769 - accuracy: 0.9287
# Epoch 00009: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1769 - accuracy: 0.9287 - val_loss: 0.1194 - val_accuracy: 0.9444
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.9266
# Epoch 00010: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1870 - accuracy: 0.9266 - val_loss: 0.1377 - val_accuracy: 0.9259
#               precision    recall  f1-score   support
#
#     COVID-19       0.67      1.00      0.80        30
#       NORMAL       0.85      0.77      0.81        30
#    PNEUMONIA       1.00      0.60      0.75        30
#
#     accuracy                           0.79        90
#    macro avg       0.84      0.79      0.79        90
# weighted avg       0.84      0.79      0.79        90
#
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4594 - accuracy: 0.7889
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4594 - accuracy: 0.7889
# (Loss, Acc): [0.4594137370586395, 0.7888888716697693]
#
# Fold  7
# [INFO] training head...
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6863 - accuracy: 0.7233
# Epoch 00001: val_loss did not improve from 0.03776
# 60/60 [==============================] - 7s 112ms/step - loss: 0.6863 - accuracy: 0.7233 - val_loss: 0.1958 - val_accuracy: 0.9444
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3787 - accuracy: 0.8658
# Epoch 00002: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.3787 - accuracy: 0.8658 - val_loss: 0.1429 - val_accuracy: 0.9444
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2855 - accuracy: 0.9036
# Epoch 00003: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.2855 - accuracy: 0.9036 - val_loss: 0.1167 - val_accuracy: 0.9444
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2600 - accuracy: 0.9119
# Epoch 00004: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.2600 - accuracy: 0.9119 - val_loss: 0.1957 - val_accuracy: 0.9444
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 0.9161
# Epoch 00005: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2222 - accuracy: 0.9161 - val_loss: 0.1313 - val_accuracy: 0.9444
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9182
# Epoch 00006: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.2022 - accuracy: 0.9182 - val_loss: 0.0910 - val_accuracy: 0.9444
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9287
# Epoch 00007: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1976 - accuracy: 0.9287 - val_loss: 0.0926 - val_accuracy: 0.9444
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9203
# Epoch 00008: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.2058 - accuracy: 0.9203 - val_loss: 0.0654 - val_accuracy: 0.9815
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9350
# Epoch 00009: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1877 - accuracy: 0.9350 - val_loss: 0.1129 - val_accuracy: 0.9444
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1474 - accuracy: 0.9371
# Epoch 00010: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1474 - accuracy: 0.9371 - val_loss: 0.1875 - val_accuracy: 0.9259
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1886 - accuracy: 0.9434
# Epoch 00011: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1886 - accuracy: 0.9434 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9458
# Epoch 00012: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1332 - accuracy: 0.9458 - val_loss: 0.1393 - val_accuracy: 0.9444
# Epoch 13/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9438
# Epoch 00013: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 102ms/step - loss: 0.1608 - accuracy: 0.9438 - val_loss: 0.0705 - val_accuracy: 0.9444
# Epoch 14/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.9455
# Epoch 00014: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1536 - accuracy: 0.9455 - val_loss: 0.2040 - val_accuracy: 0.9259
# Epoch 15/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9413
# Epoch 00015: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1457 - accuracy: 0.9413 - val_loss: 0.1222 - val_accuracy: 0.9444
# Epoch 16/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9644
# Epoch 00016: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1163 - accuracy: 0.9644 - val_loss: 0.1355 - val_accuracy: 0.9444
#               precision    recall  f1-score   support
#
#     COVID-19       0.91      0.97      0.94        30
#       NORMAL       0.78      0.83      0.81        30
#    PNEUMONIA       0.88      0.77      0.82        30
#
#     accuracy                           0.86        90
#    macro avg       0.86      0.86      0.85        90
# weighted avg       0.86      0.86      0.85        90
#
# 3/3 [==============================] - 0s 72ms/step - loss: 0.3349 - accuracy: 0.8556
# 3/3 [==============================] - 0s 73ms/step - loss: 0.3349 - accuracy: 0.8556
# (Loss, Acc): [0.3348686993122101, 0.855555534362793]
#
# Fold  8
# [INFO] training head...
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7397 - accuracy: 0.7044
# Epoch 00001: val_loss did not improve from 0.03776
# 60/60 [==============================] - 7s 114ms/step - loss: 0.7397 - accuracy: 0.7044 - val_loss: 0.2162 - val_accuracy: 0.9259
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3687 - accuracy: 0.8470
# Epoch 00002: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.3687 - accuracy: 0.8470 - val_loss: 0.4637 - val_accuracy: 0.8333
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2848 - accuracy: 0.8868
# Epoch 00003: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2848 - accuracy: 0.8868 - val_loss: 0.2010 - val_accuracy: 0.9444
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.9078
# Epoch 00004: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.2543 - accuracy: 0.9078 - val_loss: 0.1735 - val_accuracy: 0.9444
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9099
# Epoch 00005: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1992 - accuracy: 0.9099 - val_loss: 0.2533 - val_accuracy: 0.8889
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9036
# Epoch 00006: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.2235 - accuracy: 0.9036 - val_loss: 0.2294 - val_accuracy: 0.9074
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2194 - accuracy: 0.9140
# Epoch 00007: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.2194 - accuracy: 0.9140 - val_loss: 0.1094 - val_accuracy: 0.9630
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1807 - accuracy: 0.9245
# Epoch 00008: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1807 - accuracy: 0.9245 - val_loss: 0.1485 - val_accuracy: 0.9259
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1631 - accuracy: 0.9413
# Epoch 00009: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1631 - accuracy: 0.9413 - val_loss: 0.0985 - val_accuracy: 0.9630
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1823 - accuracy: 0.9329
# Epoch 00010: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1823 - accuracy: 0.9329 - val_loss: 0.1936 - val_accuracy: 0.9259
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1350 - accuracy: 0.9434
# Epoch 00011: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1350 - accuracy: 0.9434 - val_loss: 0.2690 - val_accuracy: 0.8889
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9350
# Epoch 00012: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1485 - accuracy: 0.9350 - val_loss: 0.1606 - val_accuracy: 0.9259
# Epoch 13/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1620 - accuracy: 0.9287
# Epoch 00013: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 99ms/step - loss: 0.1620 - accuracy: 0.9287 - val_loss: 0.2061 - val_accuracy: 0.9074
# Epoch 14/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9518
# Epoch 00014: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1389 - accuracy: 0.9518 - val_loss: 0.1227 - val_accuracy: 0.9444
#               precision    recall  f1-score   support
#
#     COVID-19       0.88      0.97      0.92        30
#       NORMAL       0.86      0.80      0.83        30
#    PNEUMONIA       0.90      0.87      0.88        30
#
#     accuracy                           0.88        90
#    macro avg       0.88      0.88      0.88        90
# weighted avg       0.88      0.88      0.88        90
#
# 3/3 [==============================] - 0s 73ms/step - loss: 0.3018 - accuracy: 0.8778
# 3/3 [==============================] - 0s 73ms/step - loss: 0.3018 - accuracy: 0.8778
# (Loss, Acc): [0.30181193351745605, 0.8777777552604675]
#
# Fold  9
# [INFO] training head...
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7163 - accuracy: 0.7197
# Epoch 00001: val_loss did not improve from 0.03776
# 60/60 [==============================] - 7s 119ms/step - loss: 0.7163 - accuracy: 0.7197 - val_loss: 0.4018 - val_accuracy: 0.8491
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3919 - accuracy: 0.8452
# Epoch 00002: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.3919 - accuracy: 0.8452 - val_loss: 0.2764 - val_accuracy: 0.8868
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3030 - accuracy: 0.8828
# Epoch 00003: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 103ms/step - loss: 0.3030 - accuracy: 0.8828 - val_loss: 0.3044 - val_accuracy: 0.8679
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.9079
# Epoch 00004: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 103ms/step - loss: 0.2607 - accuracy: 0.9079 - val_loss: 0.3768 - val_accuracy: 0.8679
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9268
# Epoch 00005: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1995 - accuracy: 0.9268 - val_loss: 0.3354 - val_accuracy: 0.8679
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2422 - accuracy: 0.9059
# Epoch 00006: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.2422 - accuracy: 0.9059 - val_loss: 0.2549 - val_accuracy: 0.8868
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9226
# Epoch 00007: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1889 - accuracy: 0.9226 - val_loss: 0.2528 - val_accuracy: 0.8868
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9184
# Epoch 00008: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.2084 - accuracy: 0.9184 - val_loss: 0.1613 - val_accuracy: 0.9057
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1765 - accuracy: 0.9372
# Epoch 00009: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1765 - accuracy: 0.9372 - val_loss: 0.1532 - val_accuracy: 0.9057
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9477
# Epoch 00010: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1496 - accuracy: 0.9477 - val_loss: 0.1979 - val_accuracy: 0.9245
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1803 - accuracy: 0.9351
# Epoch 00011: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1803 - accuracy: 0.9351 - val_loss: 0.2272 - val_accuracy: 0.9245
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1413 - accuracy: 0.9477
# Epoch 00012: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1413 - accuracy: 0.9477 - val_loss: 0.1873 - val_accuracy: 0.9434
# Epoch 13/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1646 - accuracy: 0.9372
# Epoch 00013: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1646 - accuracy: 0.9372 - val_loss: 0.2350 - val_accuracy: 0.9245
# Epoch 14/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.9498
# Epoch 00014: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1218 - accuracy: 0.9498 - val_loss: 0.1452 - val_accuracy: 0.9057
# Epoch 15/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.9519
# Epoch 00015: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1334 - accuracy: 0.9519 - val_loss: 0.2063 - val_accuracy: 0.9245
# Epoch 16/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1566 - accuracy: 0.9393
# Epoch 00016: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 102ms/step - loss: 0.1566 - accuracy: 0.9393 - val_loss: 0.1439 - val_accuracy: 0.9245
# Epoch 17/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9540
# Epoch 00017: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 102ms/step - loss: 0.1240 - accuracy: 0.9540 - val_loss: 0.1622 - val_accuracy: 0.9057
# Epoch 18/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9582
# Epoch 00018: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 100ms/step - loss: 0.1116 - accuracy: 0.9582 - val_loss: 0.1898 - val_accuracy: 0.9057
# Epoch 19/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9540
# Epoch 00019: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1079 - accuracy: 0.9540 - val_loss: 0.3148 - val_accuracy: 0.9057
# Epoch 20/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9435
# Epoch 00020: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1313 - accuracy: 0.9435 - val_loss: 0.1928 - val_accuracy: 0.9057
# Epoch 21/30
# 60/60 [==============================] - ETA: 0s - loss: 0.1508 - accuracy: 0.9435
# Epoch 00021: val_loss did not improve from 0.03776
# 60/60 [==============================] - 6s 101ms/step - loss: 0.1508 - accuracy: 0.9435 - val_loss: 0.1885 - val_accuracy: 0.9057
#               precision    recall  f1-score   support
#
#     COVID-19       0.88      0.97      0.92        30
#       NORMAL       0.83      0.80      0.81        30
#    PNEUMONIA       0.89      0.83      0.86        30
#
#     accuracy                           0.87        90
#    macro avg       0.87      0.87      0.87        90
# weighted avg       0.87      0.87      0.87        90
#
# 3/3 [==============================] - 0s 72ms/step - loss: 0.3624 - accuracy: 0.8667
# 3/3 [==============================] - 0s 72ms/step - loss: 0.3624 - accuracy: 0.8667
# (Loss, Acc): [0.3623529076576233, 0.8666666746139526]

# %%
test_acc = []
train_acc = []
val_acc = []

for i in range(10):
  H = HXs[i]
  train_acc.append(np.mean(HXs[i].history["accuracy"]))
  val_acc.append(np.mean(HXs[i].history["val_accuracy"]))
  test_acc.append(models_evaluations[i][1])

test_acc_mean = np.mean(test_acc)
train_acc_mean = np.mean(train_acc)
val_acc_mean = np.mean(val_acc)
print(" train accuracy mean:",train_acc_mean,"\n",
      "validation accuracy mean:",val_acc_mean,"\n",
      "test accuracy mean:",test_acc_mean)
# Out:
#  train accuracy mean: 0.9105317454482383
#  validation accuracy mean: 0.9214945067237693
#  test accuracy mean: 0.8599999904632568

# %%
for i in range(len(HXs)):
  H = HXs[i]
  N = len(H.history["accuracy"])
  plt.figure()
  plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
  plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
  plt.title("Fold"+ str(i)+" Training Accuracy on COVID-19 Dataset")
  plt.xlabel("Epoch #")
  plt.ylabel("Accuracy")
  plt.legend(loc="lower left")
  plt.savefig("/content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Fold_"+ str(i)+'ResNet50_Training_Accuracy.png', bbox_inches='tight')

# %%
for i in range(len(HXs)):
  H = HXs[i]
  N = len(H.history["accuracy"])
  plt.figure()
  plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
  plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
  plt.title("Fold"+ str(i)+"Training Loss on COVID-19 Dataset")
  plt.xlabel("Epoch #")
  plt.ylabel("Loss")
  plt.legend(loc="lower left")
  plt.savefig('/content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Fold_'+ str(i) +'ResNet50_Training_Loss.png', bbox_inches='tight')

# %%
modelX = ResNet50_get()

HX = modelX.fit_generator(
    trainAug.flow(train_list, train_labels, batch_size=8),
    steps_per_epoch=len(train_list) // 8,
    validation_data=(test_list, test_labels),
    validation_steps=len(test_list) // 8,
    callbacks=[early_stopping_callback, checkpoint_callback],
    epochs=30)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# WARNING:tensorflow:From <ipython-input-15-adf50aa4a386>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7307 - accuracy: 0.7194WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00001: val_loss improved from inf to 0.50605, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 67/67 [==============================] - 10s 155ms/step - loss: 0.7307 - accuracy: 0.7194 - val_loss: 0.5060 - val_accuracy: 0.8111
# Epoch 2/30
# 67/67 [==============================] - ETA: 0s - loss: 0.3403 - accuracy: 0.8757WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00002: val_loss improved from 0.50605 to 0.45659, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 67/67 [==============================] - 7s 105ms/step - loss: 0.3403 - accuracy: 0.8757 - val_loss: 0.4566 - val_accuracy: 0.7778
# Epoch 3/30
# 67/67 [==============================] - ETA: 0s - loss: 0.2742 - accuracy: 0.9002WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00003: val_loss improved from 0.45659 to 0.45016, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 67/67 [==============================] - 7s 104ms/step - loss: 0.2742 - accuracy: 0.9002 - val_loss: 0.4502 - val_accuracy: 0.7889
# Epoch 4/30
# 67/67 [==============================] - ETA: 0s - loss: 0.2341 - accuracy: 0.9153WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00004: val_loss improved from 0.45016 to 0.41258, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 67/67 [==============================] - 7s 104ms/step - loss: 0.2341 - accuracy: 0.9153 - val_loss: 0.4126 - val_accuracy: 0.7889
# Epoch 5/30
# 67/67 [==============================] - ETA: 0s - loss: 0.2239 - accuracy: 0.9171WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00005: val_loss did not improve from 0.41258
# 67/67 [==============================] - 6s 93ms/step - loss: 0.2239 - accuracy: 0.9171 - val_loss: 0.6789 - val_accuracy: 0.7889
# Epoch 6/30
# 67/67 [==============================] - ETA: 0s - loss: 0.2452 - accuracy: 0.9040WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00006: val_loss improved from 0.41258 to 0.28372, saving model to /content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_best_fold.h5
# 67/67 [==============================] - 8s 115ms/step - loss: 0.2452 - accuracy: 0.9040 - val_loss: 0.2837 - val_accuracy: 0.9111
# Epoch 7/30
# 67/67 [==============================] - ETA: 0s - loss: 0.2552 - accuracy: 0.9049WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00007: val_loss did not improve from 0.28372
# 67/67 [==============================] - 6s 95ms/step - loss: 0.2552 - accuracy: 0.9049 - val_loss: 0.2908 - val_accuracy: 0.8556
# Epoch 8/30
# 67/67 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9322WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00008: val_loss did not improve from 0.28372
# 67/67 [==============================] - 6s 95ms/step - loss: 0.1703 - accuracy: 0.9322 - val_loss: 0.3463 - val_accuracy: 0.8667
# Epoch 9/30
# 67/67 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9266WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00009: val_loss did not improve from 0.28372
# 67/67 [==============================] - 6s 92ms/step - loss: 0.1821 - accuracy: 0.9266 - val_loss: 0.5599 - val_accuracy: 0.7444
# Epoch 10/30
# 67/67 [==============================] - ETA: 0s - loss: 0.1721 - accuracy: 0.9435WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00010: val_loss did not improve from 0.28372
# 67/67 [==============================] - 6s 92ms/step - loss: 0.1721 - accuracy: 0.9435 - val_loss: 0.4302 - val_accuracy: 0.8667
# Epoch 11/30
# 67/67 [==============================] - ETA: 0s - loss: 0.1673 - accuracy: 0.9247WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 11 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00011: val_loss did not improve from 0.28372
# 67/67 [==============================] - 6s 94ms/step - loss: 0.1673 - accuracy: 0.9247 - val_loss: 0.3501 - val_accuracy: 0.8889

# %%
K.set_learning_phase(0)
predIdxsX = modelX.predict(test_list.astype('float16'), batch_size=15)
predIdxsX = np.argmax(predIdxsX, axis=1)
print(classification_report(test_labels.argmax(axis=1), predIdxsX,target_names=["COVID-19","NORMAL","PNEUMONIA"]))
# Out:
#               precision    recall  f1-score   support
#
#     COVID-19       0.94      0.97      0.95        30
#       NORMAL       0.63      0.90      0.74        30
#    PNEUMONIA       0.94      0.50      0.65        30
#
#     accuracy                           0.79        90
#    macro avg       0.83      0.79      0.78        90
# weighted avg       0.83      0.79      0.78        90

# %%
Loss, Acc = modelX.evaluate(test_list,test_labels)
print("(Loss, Acc):",modelX.evaluate(test_list,test_labels))
# Out:
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4873 - accuracy: 0.7889
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4873 - accuracy: 0.7889
# (Loss, Acc): [0.48728910088539124, 0.7888888716697693]

# %%
H = HX
N = len(H.history["accuracy"])
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.title("Fold"+ str(i)+"Training Loss on COVID-19 Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")
plt.savefig("/content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/ResNet50_final_model_Training_Loss.png", bbox_inches='tight')

# %%
H = HX
N = len(H.history["accuracy"])
plt.figure()
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_accuracy")
plt.title("Fold"+ str(i)+"Training Accuracy on COVID-19 Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")
plt.savefig("/content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/ResNet50_final_model_Training_Accuracy.png", bbox_inches='tight')

# %%
modelX.save("/content/drive/My Drive/Colab Notebooks/Covid_19_ResNet50/Covid_19_ResNet50_final_model.h5")
